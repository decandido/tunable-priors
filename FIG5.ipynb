# %%
import matplotlib.pyplot as plt
import numpy as np
import pandas as pd
plt.rcParams['savefig.facecolor']='white'

# %%
df1=pd.read_csv('./compare_results/cs_compare_test_hq_8bit/cs_k.csv')
df2=pd.read_csv('./compare_results/cs_compare_test_hq_8bit2/cs_k.csv')
df3=pd.read_csv('./compare_results/cs_compare_test_hq_8bit3/cs_k.csv')
df4=pd.read_csv('./compare_results/cs_compare_test_hq_8bit4/cs_k.csv')
df_nf=pd.concat([df1,df2,df3,df4],ignore_index=True)

df_nf_m_15=np.mean(df_nf['PSNR'][df_nf.M==15.0][df_nf.K==15])
df_nf_m_10=np.mean(df_nf['PSNR'][df_nf.M==10.0][df_nf.K==10])
df_nf_m_7_5=np.mean(df_nf['PSNR'][df_nf.M==7.5][df_nf.K==7.5])
df_nf_m_5=np.mean(df_nf['PSNR'][df_nf.M==5][df_nf.K==5])
df_nf_m_2_5=np.mean(df_nf['PSNR'][df_nf.M==2.5][df_nf.K==2.5])
df_nf_m_1=np.mean(df_nf['PSNR'][df_nf.M==1][df_nf.K==1])

cs_tun_nf_mean_results=np.array((df_nf_m_15,df_nf_m_10,df_nf_m_7_5,df_nf_m_5,df_nf_m_2_5,df_nf_m_1))

df_nf_m_15=1.96*(np.std(df_nf['PSNR'][df_nf.M==15.0][df_nf.K==15]))/np.sqrt(100)
df_nf_m_10=1.96*(np.std(df_nf['PSNR'][df_nf.M==10.0][df_nf.K==10]))/np.sqrt(100)
df_nf_m_7_5=1.96*(np.std(df_nf['PSNR'][df_nf.M==7.5][df_nf.K==7.5]))/np.sqrt(100)
df_nf_m_5=1.96*(np.std(df_nf['PSNR'][df_nf.M==5][df_nf.K==5]))/np.sqrt(100)
df_nf_m_2_5=1.96*(np.std(df_nf['PSNR'][df_nf.M==2.5][df_nf.K==2.5]))/np.sqrt(100)
df_nf_m_1=1.96*(np.std(df_nf['PSNR'][df_nf.M==1][df_nf.K==1]))/np.sqrt(100)

cs_tun_nf_std_results=np.array((df_nf_m_15,df_nf_m_10,df_nf_m_7_5,df_nf_m_5,df_nf_m_2_5,df_nf_m_1))

df_nf_m_15=np.mean(df_nf['PSNR'][df_nf.M==15.0][df_nf.K==100])
df_nf_m_10=np.mean(df_nf['PSNR'][df_nf.M==10.0][df_nf.K==100])
df_nf_m_7_5=np.mean(df_nf['PSNR'][df_nf.M==7.5][df_nf.K==100])
df_nf_m_5=np.mean(df_nf['PSNR'][df_nf.M==5][df_nf.K==100])
df_nf_m_2_5=np.mean(df_nf['PSNR'][df_nf.M==2.5][df_nf.K==100])
df_nf_m_1=np.mean(df_nf['PSNR'][df_nf.M==1][df_nf.K==100])

cs_van_nf_mean_results=np.array((df_nf_m_15,df_nf_m_10,df_nf_m_7_5,df_nf_m_5,df_nf_m_2_5,df_nf_m_1))

df_nf_m_15=1.96*(np.std(df_nf['PSNR'][df_nf.M==15.0][df_nf.K==100]))/np.sqrt(100)
df_nf_m_10=1.96*(np.std(df_nf['PSNR'][df_nf.M==10.0][df_nf.K==100]))/np.sqrt(100)
df_nf_m_7_5=1.96*(np.std(df_nf['PSNR'][df_nf.M==7.5][df_nf.K==100]))/np.sqrt(100)
df_nf_m_5=1.96*(np.std(df_nf['PSNR'][df_nf.M==5][df_nf.K==100]))/np.sqrt(100)
df_nf_m_2_5=1.96*(np.std(df_nf['PSNR'][df_nf.M==2.5][df_nf.K==100]))/np.sqrt(100)
df_nf_m_1=1.96*(np.std(df_nf['PSNR'][df_nf.M==1][df_nf.K==100]))/np.sqrt(100)

cs_van_nf_std_results=np.array((df_nf_m_15,df_nf_m_10,df_nf_m_7_5,df_nf_m_5,df_nf_m_2_5,df_nf_m_1))

# %%
df_dec=pd.read_csv('./compare_results/cs_deep_decoder_test_celebahq/cs_k.csv')

df_dec_m_15=np.mean(df_dec['PSNR'][df_dec.M==15])
df_dec_m_10=np.mean(df_dec['PSNR'][df_dec.M==10])
df_dec_m_7_5=np.mean(df_dec['PSNR'][df_dec.M==7.5])
df_dec_m_5=np.mean(df_dec['PSNR'][df_dec.M==5])
df_dec_m_2_5=np.mean(df_dec['PSNR'][df_dec.M==2.5])
df_dec_m_1=np.mean(df_dec['PSNR'][df_dec.M==1])

dd_score_mean=np.array((df_dec_m_15,df_dec_m_10,df_dec_m_7_5,df_dec_m_5,df_dec_m_2_5,df_dec_m_1))

df_dec_m_15=np.std(df_dec['PSNR'][df_dec.M==15])/np.sqrt(100)
df_dec_m_10=np.std(df_dec['PSNR'][df_dec.M==10])/np.sqrt(100)
df_dec_m_7_5=np.std(df_dec['PSNR'][df_dec.M==7.5])/np.sqrt(100)
df_dec_m_5=np.std(df_dec['PSNR'][df_dec.M==5])/np.sqrt(100)
df_dec_m_2_5=np.std(df_dec['PSNR'][df_dec.M==2.5])/np.sqrt(100)
df_dec_m_1=np.std(df_dec['PSNR'][df_dec.M==1])/np.sqrt(100)

dd_score_std=1.96*np.array((df_dec_m_15,df_dec_m_10,df_dec_m_7_5,df_dec_m_5,df_dec_m_2_5,df_dec_m_1))

# %%
arr_sc_m_15=np.load('./compare_results/celeba_HQ15/CELEBA/linear/psnr_mean_210000.npy') 
arr_sc_m_10=np.load('./compare_results/celeba_HQ10/CELEBA/linear/psnr_mean_210000.npy') 
arr_sc_m_7_5=np.load('./compare_results/celeba_HQ7.5/CELEBA/linear/psnr_mean_210000.npy') 
arr_sc_m_5=np.load('./compare_results/celeba_HQ5/CELEBA/linear/psnr_mean_210000.npy') 
arr_sc_m_2_5=np.load('./compare_results/celeba_HQ2.5/CELEBA/linear/psnr_mean_210000.npy') 
arr_sc_m_1=np.load('./compare_results/celeba_HQ1/CELEBA/linear/psnr_mean_210000.npy') 
cs_score_mean=np.array((arr_sc_m_15,arr_sc_m_10,arr_sc_m_7_5,arr_sc_m_5,arr_sc_m_2_5,arr_sc_m_1))

arr_sc_m_15=np.load('./compare_results/celeba_HQ15/CELEBA/linear/psnr_std_210000.npy') 
arr_sc_m_10=np.load('./compare_results/celeba_HQ10/CELEBA/linear/psnr_std_210000.npy') 
arr_sc_m_7_5=np.load('./compare_results/celeba_HQ7.5/CELEBA/linear/psnr_std_210000.npy') 
arr_sc_m_5=np.load('./compare_results/celeba_HQ5/CELEBA/linear/psnr_std_210000.npy') 
arr_sc_m_2_5=np.load('./compare_results/celeba_HQ2.5/CELEBA/linear/psnr_std_210000.npy') 
arr_sc_m_1=np.load('./compare_results/celeba_HQ1/CELEBA/linear/psnr_std_210000.npy') 
cs_score_std=1.96*np.array((arr_sc_m_15,arr_sc_m_10,arr_sc_m_7_5,arr_sc_m_5,arr_sc_m_2_5,arr_sc_m_1))/np.sqrt(100)
cs_score_mean
# Out:
# array([30.96750376, 28.6550017 , 26.69261717, 23.36413106, 18.07851989,
#        13.57369499])

# %%
plt.figure(figsize=(8,6))
cs_hq=np.array((15,10,7.5,5,2.5,1))/100
plt.errorbar(cs_hq,cs_tun_nf_mean_results,yerr=cs_tun_nf_std_results,marker='o',markersize=7,capsize=7,color='blue',label='Our Method')
plt.errorbar(cs_hq,cs_van_nf_mean_results,yerr=cs_van_nf_std_results,marker='o',markersize=7,capsize=7,color='orange',label='NF')
plt.errorbar(cs_hq,dd_score_mean,yerr=dd_score_std,marker='o',markersize=7,capsize=7,color='violet',label='DD')
plt.errorbar(cs_hq,cs_score_mean,yerr=cs_score_std,marker='o',markersize=7,capsize=7,color='red',label='CS-SGM ')
plt.xlabel('Undersampling Ratio  m/n',fontsize=20)
plt.ylabel('Reconstruction Error PSNR (dB)',fontsize=20)
plt.legend()
plt.title('CELBA HQ',size=20)
plt.grid()
plt.tight_layout()

# %%
df1=pd.read_csv('./compare_results/cs_compare_test_FFhq_8bit/cs_k.csv')
df2=pd.read_csv('./compare_results/cs_compare_test_FFhq_8bit2/cs_k.csv')
df3=pd.read_csv('./compare_results/cs_compare_test_FFhq_8bit3/cs_k.csv')
df4=pd.read_csv('./compare_results/cs_compare_test_FFhq_8bit4/cs_k.csv')
df_nf=pd.concat([df1,df2,df3,df4],ignore_index=True)

df_nf_m_25=np.mean(df_nf['PSNR'][df_nf.M==25.0][df_nf.K==25])
df_nf_m_20=np.mean(df_nf['PSNR'][df_nf.M==20.0][df_nf.K==20])
df_nf_m_15=np.mean(df_nf['PSNR'][df_nf.M==15][df_nf.K==15])
df_nf_m_10=np.mean(df_nf['PSNR'][df_nf.M==10][df_nf.K==10])
df_nf_m_5=np.mean(df_nf['PSNR'][df_nf.M==5][df_nf.K==5])
df_nf_m_1=np.mean(df_nf['PSNR'][df_nf.M==1][df_nf.K==1])

cs_tun_nf_mean_results_ffhq=np.array((df_nf_m_25,df_nf_m_20,df_nf_m_15,df_nf_m_10,df_nf_m_5,df_nf_m_1))

df_nf_m_25=1.96*(np.std(df_nf['PSNR'][df_nf.M==25.0][df_nf.K==25])/np.sqrt(100))
df_nf_m_20=1.96*(np.std(df_nf['PSNR'][df_nf.M==20.0][df_nf.K==20])/np.sqrt(100))
df_nf_m_15=1.96*(np.std(df_nf['PSNR'][df_nf.M==15][df_nf.K==15])/np.sqrt(100))
df_nf_m_10=1.96*(np.std(df_nf['PSNR'][df_nf.M==10][df_nf.K==10])/np.sqrt(100))
df_nf_m_5=1.96*(np.std(df_nf['PSNR'][df_nf.M==5][df_nf.K==5])/np.sqrt(100))
df_nf_m_1=1.96*(np.std(df_nf['PSNR'][df_nf.M==1][df_nf.K==1])/np.sqrt(100))

cs_tun_nf_std_results_ffhq=np.array((df_nf_m_25,df_nf_m_20,df_nf_m_15,df_nf_m_10,df_nf_m_5,df_nf_m_1))


df_nf_m_25=np.mean(df_nf['PSNR'][df_nf.M==25.0][df_nf.K==100])
df_nf_m_20=np.mean(df_nf['PSNR'][df_nf.M==20.0][df_nf.K==100])
df_nf_m_15=np.mean(df_nf['PSNR'][df_nf.M==15][df_nf.K==100])
df_nf_m_10=np.mean(df_nf['PSNR'][df_nf.M==10][df_nf.K==100])
df_nf_m_5=np.mean(df_nf['PSNR'][df_nf.M==5][df_nf.K==100])
df_nf_m_1=np.mean(df_nf['PSNR'][df_nf.M==1][df_nf.K==100])

cs_van_nf_mean_results_ffhq=np.array((df_nf_m_25,df_nf_m_20,df_nf_m_15,df_nf_m_10,df_nf_m_5,df_nf_m_1))

df_nf_m_25=1.96*(np.std(df_nf['PSNR'][df_nf.M==25.0][df_nf.K==100])/np.sqrt(100))
df_nf_m_20=1.96*(np.std(df_nf['PSNR'][df_nf.M==20.0][df_nf.K==100])/np.sqrt(100))
df_nf_m_15=1.96*(np.std(df_nf['PSNR'][df_nf.M==15][df_nf.K==100])/np.sqrt(100))
df_nf_m_10=1.96*(np.std(df_nf['PSNR'][df_nf.M==10][df_nf.K==100])/np.sqrt(100))
df_nf_m_5=1.96*(np.std(df_nf['PSNR'][df_nf.M==5][df_nf.K==100])/np.sqrt(100))
df_nf_m_1=1.96*(np.std(df_nf['PSNR'][df_nf.M==1][df_nf.K==100])/np.sqrt(100))

cs_van_nf_std_results_ffhq=np.array((df_nf_m_25,df_nf_m_20,df_nf_m_15,df_nf_m_10,df_nf_m_5,df_nf_m_1))

# %%
df_dec=pd.read_csv('./compare_results/cs_deep_decoder_test_ffhq/cs_k.csv')

df_dec_m_25=np.mean(df_dec['PSNR'][df_dec.K==250][df_dec.M==25])
df_dec_m_20=np.mean(df_dec['PSNR'][df_dec.K==250][df_dec.M==20])
df_dec_m_15=np.mean(df_dec['PSNR'][df_dec.K==250][df_dec.M==15])
df_dec_m_10=np.mean(df_dec['PSNR'][df_dec.K==250][df_dec.M==10])
df_dec_m_5=np.mean(df_dec['PSNR'][df_dec.K==250][df_dec.M==5])
df_dec_m_1=np.mean(df_dec['PSNR'][df_dec.K==250][df_dec.M==1])

dd_score_mean_ffhq=np.array((df_dec_m_25,df_dec_m_20,df_dec_m_15,df_dec_m_10,df_dec_m_5,df_dec_m_1))

df_dec_m_25=np.std(df_dec['PSNR'][df_dec.K==250][df_dec.M==25])/np.sqrt(100)
df_dec_m_20=np.std(df_dec['PSNR'][df_dec.K==250][df_dec.M==20])/np.sqrt(100)
df_dec_m_15=np.std(df_dec['PSNR'][df_dec.K==250][df_dec.M==15])/np.sqrt(100)
df_dec_m_10=np.std(df_dec['PSNR'][df_dec.K==250][df_dec.M==10])/np.sqrt(100)
df_dec_m_5=np.std(df_dec['PSNR'][df_dec.K==250][df_dec.M==5])/np.sqrt(100)
df_dec_m_1=np.std(df_dec['PSNR'][df_dec.K==250][df_dec.M==1])/np.sqrt(100)

dd_score_std_ffhq=1.96*np.array((df_dec_m_25,df_dec_m_20,df_dec_m_15,df_dec_m_10,df_dec_m_5,df_dec_m_1))

# %%
arr_sc_m_25=np.load('./compare_results/FFHQ25/CELEBA/linear/psnr_mean_210000.npy') 
arr_sc_m_20=np.load('./compare_results/FFHQ20/CELEBA/linear/psnr_mean_210000.npy') 
arr_sc_m_15=np.load('./compare_results/FFHQ15/CELEBA/linear/psnr_mean_210000.npy') 
arr_sc_m_10=np.load('./compare_results/FFHQ10/CELEBA/linear/psnr_mean_210000.npy') 
arr_sc_m_5=np.load('./compare_results/FFHQ5/CELEBA/linear/psnr_mean_210000.npy') 
arr_sc_m_1=np.load('./compare_results/celeba_HQ1/CELEBA/linear/psnr_mean_210000.npy') 
cs_score_mean_ffhq=np.array((arr_sc_m_25,arr_sc_m_20,arr_sc_m_15,arr_sc_m_10,arr_sc_m_5,arr_sc_m_1))

arr_sc_m_25=np.load('./compare_results/FFHQ25/CELEBA/linear/psnr_std_210000.npy') 
arr_sc_m_20=np.load('./compare_results/FFHQ20/CELEBA/linear/psnr_std_210000.npy') 
arr_sc_m_15=np.load('./compare_results/FFHQ15/CELEBA/linear/psnr_std_210000.npy') 
arr_sc_m_10=np.load('./compare_results/FFHQ10/CELEBA/linear/psnr_std_210000.npy') 
arr_sc_m_5=np.load('./compare_results/FFHQ5/CELEBA/linear/psnr_std_210000.npy') 
arr_sc_m_1_ffhq=np.load('./compare_results/FFHQ1/CELEBA/linear/psnr_std_210000.npy') 

cs_score_std_ffhq=1.96*np.array((arr_sc_m_25,arr_sc_m_20,arr_sc_m_15,arr_sc_m_10,arr_sc_m_5,arr_sc_m_1))/np.sqrt(100)

# %%
plt.figure(figsize=(8,6))
cs_ffhq=np.array((25,20,15,10,5,1))/100
plt.errorbar(cs_ffhq,cs_tun_nf_mean_results_ffhq,yerr=cs_tun_nf_std_results_ffhq,marker='o',markersize=7,capsize=7,color='blue',label='Our Method')
plt.errorbar(cs_ffhq,cs_van_nf_mean_results_ffhq,yerr=cs_van_nf_std_results_ffhq,marker='o',markersize=7,capsize=7,color='orange',label='NF')
plt.errorbar(cs_ffhq,dd_score_mean_ffhq,yerr=dd_score_std_ffhq,marker='o',markersize=7,capsize=7,color='violet',label='DD')
plt.errorbar(cs_ffhq,cs_score_mean_ffhq,yerr=cs_score_std_ffhq,marker='o',markersize=7,capsize=7,color='red',label='CS-SGM ')
plt.xlabel('Undersampling Ratio  m/n',fontsize=20)
plt.ylabel('Reconstruction Error PSNR (dB)',fontsize=20)
plt.legend()
plt.title('FFHQ',size=20)
plt.grid()
plt.tight_layout()

# %%
fig, (ax1, ax2) = plt.subplots(1, 2)
fig = plt.gcf()
fig.set_size_inches(15,12)

ax1.errorbar(cs_hq,cs_tun_nf_mean_results,yerr=cs_tun_nf_std_results,marker='o',markersize=7,capsize=7,color='blue',label='Our Method')
ax1.errorbar(cs_hq,cs_van_nf_mean_results,yerr=cs_van_nf_std_results,marker='o',markersize=7,capsize=7,color='orange',label='NF')
ax1.errorbar(cs_hq,dd_score_mean,yerr=dd_score_std,marker='o',markersize=7,capsize=7,color='violet',label='DD')
ax1.errorbar(cs_hq,cs_score_mean,yerr=cs_score_std,marker='o',markersize=7,capsize=7,color='red',label='CS-SGM ')
ax1.set_xlabel('Undersampling Ratio  m/n',fontsize=25)
ax1.set_ylabel('Reconstruction Error PSNR (dB)',fontsize=25)
ax1.tick_params(axis="x", labelsize=20)
ax1.tick_params(axis="y", labelsize=20)
ax1.grid()
ax1.set_title('CelebA-HQ',fontsize=30)

ax2.errorbar(cs_ffhq,cs_tun_nf_mean_results_ffhq,yerr=cs_tun_nf_std_results_ffhq,marker='o',markersize=7,capsize=7,color='blue')
ax2.errorbar(cs_ffhq,cs_van_nf_mean_results_ffhq,yerr=cs_van_nf_std_results_ffhq,marker='o',markersize=7,capsize=7,color='orange')
ax2.errorbar(cs_ffhq,dd_score_mean_ffhq,yerr=dd_score_std_ffhq,marker='o',markersize=7,capsize=7,color='violet')
ax2.errorbar(cs_ffhq,cs_score_mean_ffhq,yerr=cs_score_std_ffhq,marker='o',markersize=7,capsize=7,color='red')
ax2.set_xlabel('Undersampling Ratio  m/n',fontsize=25)
ax2.set_ylabel('Reconstruction Error PSNR (dB)',fontsize=25)
ax2.grid()
ax2.tick_params(axis="x", labelsize=20)
ax2.tick_params(axis="y", labelsize=20)
ax2.set_title('FFHQ',fontsize=30)



fig.legend(loc='lower center',ncol=4, bbox_to_anchor=(0.5, -.1),fontsize=25)
fig.tight_layout()
plt.suptitle('Compressed Sensing',y=1.075,fontsize=40)
plt.savefig('cs_compare.pdf',format='pdf', bbox_inches='tight',dpi=200)
plt.show()
